# %% [markdown]
# Type

# %%
print(type(10))       # <class 'int'>
print(type(3.14))     # <class 'float'>
print(type("Hello"))  # <class 'str'>
print(type(True))     # <class 'bool'>

x = [1, 2, 3]
print(type(x))  # <class 'list'>
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'list'>

# %% [markdown]
# Input

# %%
nome = input("Qual o seu nome? ")
print("Olá," + nome +"!")
# Out:
# Qual o seu nome? tiago
# Olá,tiago!

# %%
#Convertendo o valor do input para outro tipo
idade = int(input("Digite sua idade: "))
altura = float(input("Digite sua altura: "))
print("Você tem,", idade, "anos e", altura,"m de altura")
# Out:
# Digite sua idade: 30
# Digite sua altura: 180
# Você tem, 30 anos e 180.0 m de altura

# %% [markdown]
# VAR

# %%
# Python é dinâmico, então o tipo pode mudar:
x = 10
print (type(x))

x = "Sou uma string"
print (type(x))
# Out:
# <class 'int'>
# <class 'str'>
